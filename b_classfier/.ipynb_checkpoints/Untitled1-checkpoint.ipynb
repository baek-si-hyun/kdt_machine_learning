# %%
import pandas as pd

ap_df  = pd.read_csv('./datasets/application_record.csv')
cr_df  = pd.read_csv('./datasets/credit_record.csv')
display(ap_df)
display(cr_df)
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0               Working               Higher education
# 1               427500.0               Working               Higher education
# 2               112500.0               Working  Secondary / secondary special
# 3               270000.0  Commercial associate  Secondary / secondary special
# 4               270000.0  Commercial associate  Secondary / secondary special
# ...                  ...                   ...                            ...
# 438552          135000.0             Pensioner  Secondary / secondary special
# 438553          103500.0               Working  Secondary / secondary special
# 438554           54000.0  Commercial associate               Higher education
# 438555           72000.0             Pensioner  Secondary / secondary special
# 438556          121500.0               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage   Rented apartment      -12005          -4542
# 1             Civil marriage   Rented apartment      -12005          -4542
# 2                    Married  House / apartment      -21474          -1134
# 3       Single / not married  House / apartment      -19110          -3051
# 4       Single / not married  House / apartment      -19110          -3051
# ...                      ...                ...         ...            ...
# 438552             Separated  House / apartment      -22717         365243
# 438553  Single / not married  House / apartment      -15939          -3007
# 438554  Single / not married       With parents       -8169           -372
# 438555               Married  House / apartment      -21673         365243
# 438556               Married  House / apartment      -18858          -1201
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0                1                1           0           0             NaN
# 1                1                1           0           0             NaN
# 2                1                0           0           0  Security staff
# 3                1                0           1           1     Sales staff
# 4                1                0           1           1     Sales staff
# ...            ...              ...         ...         ...             ...
# 438552           1                0           0           0             NaN
# 438553           1                0           0           0        Laborers
# 438554           1                1           0           0     Sales staff
# 438555           1                0           0           0             NaN
# 438556           1                0           1           0     Sales staff
#
#         CNT_FAM_MEMBERS
# 0                   2.0
# 1                   2.0
# 2                   2.0
# 3                   1.0
# 4                   1.0
# ...                 ...
# 438552              1.0
# 438553              1.0
# 438554              1.0
# 438555              2.0
# 438556              2.0
#
# [438557 rows x 18 columns]
#               ID  MONTHS_BALANCE STATUS
# 0        5001711               0      X
# 1        5001711              -1      0
# 2        5001711              -2      0
# 3        5001711              -3      0
# 4        5001712               0      C
# ...          ...             ...    ...
# 1048570  5150487             -25      C
# 1048571  5150487             -26      C
# 1048572  5150487             -27      C
# 1048573  5150487             -28      C
# 1048574  5150487             -29      C
#
# [1048575 rows x 3 columns]

# %%
cr_df = cr_df.loc[cr_df.groupby('ID')['MONTHS_BALANCE'].idxmax()]
cr_df
# Out:
#               ID  MONTHS_BALANCE STATUS
# 0        5001711               0      X
# 4        5001712               0      C
# 23       5001713               0      X
# 45       5001714               0      X
# 60       5001715               0      X
# ...          ...             ...    ...
# 1048494  5150482             -11      C
# 1048512  5150483               0      X
# 1048530  5150484               0      C
# 1048543  5150485               0      0
# 1048545  5150487               0      C
#
# [45985 rows x 3 columns]

# %%
df = pd.merge(ap_df, cr_df, on='ID')
df
# Out:
#             ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      5008804           M            Y               Y             0
# 1      5008805           M            Y               Y             0
# 2      5008806           M            Y               Y             0
# 3      5008808           F            N               Y             0
# 4      5008809           F            N               Y             0
# ...        ...         ...          ...             ...           ...
# 36452  5149828           M            Y               Y             0
# 36453  5149834           F            N               Y             0
# 36454  5149838           F            N               Y             0
# 36455  5150049           F            N               Y             0
# 36456  5150337           M            N               Y             0
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0              427500.0               Working               Higher education
# 1              427500.0               Working               Higher education
# 2              112500.0               Working  Secondary / secondary special
# 3              270000.0  Commercial associate  Secondary / secondary special
# 4              270000.0  Commercial associate  Secondary / secondary special
# ...                 ...                   ...                            ...
# 36452          315000.0               Working  Secondary / secondary special
# 36453          157500.0  Commercial associate               Higher education
# 36454          157500.0             Pensioner               Higher education
# 36455          283500.0               Working  Secondary / secondary special
# 36456          112500.0               Working  Secondary / secondary special
#
#          NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0            Civil marriage   Rented apartment      -12005          -4542
# 1            Civil marriage   Rented apartment      -12005          -4542
# 2                   Married  House / apartment      -21474          -1134
# 3      Single / not married  House / apartment      -19110          -3051
# 4      Single / not married  House / apartment      -19110          -3051
# ...                     ...                ...         ...            ...
# 36452               Married  House / apartment      -17348          -2420
# 36453               Married  House / apartment      -12387          -1325
# 36454               Married  House / apartment      -12387          -1325
# 36455               Married  House / apartment      -17958           -655
# 36456  Single / not married   Rented apartment       -9188          -1193
#
#        FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0               1                1           0           0             NaN
# 1               1                1           0           0             NaN
# 2               1                0           0           0  Security staff
# 3               1                0           1           1     Sales staff
# 4               1                0           1           1     Sales staff
# ...           ...              ...         ...         ...             ...
# 36452           1                0           0           0        Managers
# 36453           1                0           1           1  Medicine staff
# 36454           1                0           1           1  Medicine staff
# 36455           1                0           0           0     Sales staff
# 36456           1                0           0           0        Laborers
#
#        CNT_FAM_MEMBERS  MONTHS_BALANCE STATUS
# 0                  2.0               0      C
# 1                  2.0               0      C
# 2                  2.0               0      C
# 3                  1.0               0      0
# 4                  1.0             -22      X
# ...                ...             ...    ...
# 36452              2.0               0      5
# 36453              2.0               0      C
# 36454              2.0               0      C
# 36455              2.0               0      2
# 36456              1.0               0      0
#
# [36457 rows x 20 columns]

# %% [markdown]
# df = pd.merge(ap_df, cr_df, on='ID')
# df

# %%
df.duplicated().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# columns_to_plot = ['CODE_GENDER','FLAG_OWN_CAR','FLAG_OWN_REALTY','CNT_CHILDREN','AMT_INCOME_TOTAL','NAME_INCOME_TYPE','NAME_EDUCATION_TYPE','NAME_FAMILY_STATUS','NAME_HOUSING_TYPE','DAYS_BIRTH','DAYS_EMPLOYED','FLAG_MOBIL','FLAG_WORK_PHONE','FLAG_PHONE','FLAG_EMAIL','OCCUPATION_TYPE','CNT_FAM_MEMBERS','MONTHS_BALANCE','STATUS']
# for column in df.columns:
#     if column not in ['ID', 'MONTHS_BALANCE', 'AMT_INCOME_TOTAL', 'DAYS_BIRTH', 'DAYS_EMPLOYED']:
#         sns.countplot(data=df, x=column, palette='Set3')
#         plt.title(f'Count of {column}')
#         plt.xticks(rotation=45)
#         plt.show()

# %%
# value_counts = df['STATUS'].value_counts()
# plt.figure(figsize=(8, 8))
# plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=90)
# plt.show()

# %%
df['STATUS'] = df['STATUS'].replace('X', '0')

# %%
df.loc[df['STATUS'] != '0', 'STATUS'] = '1'
df
# Out:
#             ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      5008804           M            Y               Y             0
# 1      5008805           M            Y               Y             0
# 2      5008806           M            Y               Y             0
# 3      5008808           F            N               Y             0
# 4      5008809           F            N               Y             0
# ...        ...         ...          ...             ...           ...
# 36452  5149828           M            Y               Y             0
# 36453  5149834           F            N               Y             0
# 36454  5149838           F            N               Y             0
# 36455  5150049           F            N               Y             0
# 36456  5150337           M            N               Y             0
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0              427500.0               Working               Higher education
# 1              427500.0               Working               Higher education
# 2              112500.0               Working  Secondary / secondary special
# 3              270000.0  Commercial associate  Secondary / secondary special
# 4              270000.0  Commercial associate  Secondary / secondary special
# ...                 ...                   ...                            ...
# 36452          315000.0               Working  Secondary / secondary special
# 36453          157500.0  Commercial associate               Higher education
# 36454          157500.0             Pensioner               Higher education
# 36455          283500.0               Working  Secondary / secondary special
# 36456          112500.0               Working  Secondary / secondary special
#
#          NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0            Civil marriage   Rented apartment      -12005          -4542
# 1            Civil marriage   Rented apartment      -12005          -4542
# 2                   Married  House / apartment      -21474          -1134
# 3      Single / not married  House / apartment      -19110          -3051
# 4      Single / not married  House / apartment      -19110          -3051
# ...                     ...                ...         ...            ...
# 36452               Married  House / apartment      -17348          -2420
# 36453               Married  House / apartment      -12387          -1325
# 36454               Married  House / apartment      -12387          -1325
# 36455               Married  House / apartment      -17958           -655
# 36456  Single / not married   Rented apartment       -9188          -1193
#
#        FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0               1                1           0           0             NaN
# 1               1                1           0           0             NaN
# 2               1                0           0           0  Security staff
# 3               1                0           1           1     Sales staff
# 4               1                0           1           1     Sales staff
# ...           ...              ...         ...         ...             ...
# 36452           1                0           0           0        Managers
# 36453           1                0           1           1  Medicine staff
# 36454           1                0           1           1  Medicine staff
# 36455           1                0           0           0     Sales staff
# 36456           1                0           0           0        Laborers
#
#        CNT_FAM_MEMBERS  MONTHS_BALANCE STATUS
# 0                  2.0               0      1
# 1                  2.0               0      1
# 2                  2.0               0      1
# 3                  1.0               0      0
# 4                  1.0             -22      0
# ...                ...             ...    ...
# 36452              2.0               0      1
# 36453              2.0               0      1
# 36454              2.0               0      1
# 36455              2.0               0      1
# 36456              1.0               0      0
#
# [36457 rows x 20 columns]

# %%
value_counts = df['STATUS'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=90)
plt.show()

# %%
df = df.drop(columns=['ID', 'MONTHS_BALANCE', 'AMT_INCOME_TOTAL', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'FLAG_PHONE', 'FLAG_EMAIL', 'FLAG_WORK_PHONE', 'FLAG_MOBIL'])
df
# Out:
#       CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0               M            Y               Y             0
# 1               M            Y               Y             0
# 2               M            Y               Y             0
# 3               F            N               Y             0
# 4               F            N               Y             0
# ...           ...          ...             ...           ...
# 36452           M            Y               Y             0
# 36453           F            N               Y             0
# 36454           F            N               Y             0
# 36455           F            N               Y             0
# 36456           M            N               Y             0
#
#            NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0                   Working               Higher education
# 1                   Working               Higher education
# 2                   Working  Secondary / secondary special
# 3      Commercial associate  Secondary / secondary special
# 4      Commercial associate  Secondary / secondary special
# ...                     ...                            ...
# 36452               Working  Secondary / secondary special
# 36453  Commercial associate               Higher education
# 36454             Pensioner               Higher education
# 36455               Working  Secondary / secondary special
# 36456               Working  Secondary / secondary special
#
#          NAME_FAMILY_STATUS  NAME_HOUSING_TYPE OCCUPATION_TYPE  \
# 0            Civil marriage   Rented apartment             NaN
# 1            Civil marriage   Rented apartment             NaN
# 2                   Married  House / apartment  Security staff
# 3      Single / not married  House / apartment     Sales staff
# 4      Single / not married  House / apartment     Sales staff
# ...                     ...                ...             ...
# 36452               Married  House / apartment        Managers
# 36453               Married  House / apartment  Medicine staff
# 36454               Married  House / apartment  Medicine staff
# 36455               Married  House / apartment     Sales staff
# 36456  Single / not married   Rented apartment        Laborers
#
#        CNT_FAM_MEMBERS STATUS
# 0                  2.0      1
# 1                  2.0      1
# 2                  2.0      1
# 3                  1.0      0
# 4                  1.0      0
# ...                ...    ...
# 36452              2.0      1
# 36453              2.0      1
# 36454              2.0      1
# 36455              2.0      1
# 36456              1.0      0
#
# [36457 rows x 11 columns]

# %%
df[df['OCCUPATION_TYPE'].isna()]
# Out:
#       CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0               M            Y               Y             0
# 1               M            Y               Y             0
# 7               F            N               Y             0
# 8               F            N               Y             0
# 9               F            N               Y             0
# ...           ...          ...             ...           ...
# 36439           M            N               Y             0
# 36440           F            N               N             0
# 36445           F            N               Y             0
# 36446           F            N               Y             0
# 36450           M            Y               Y             0
#
#            NAME_INCOME_TYPE            NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0                   Working               Higher education     Civil marriage
# 1                   Working               Higher education     Civil marriage
# 7                 Pensioner               Higher education          Separated
# 8                 Pensioner               Higher education          Separated
# 9                 Pensioner               Higher education          Separated
# ...                     ...                            ...                ...
# 36439             Pensioner  Secondary / secondary special            Married
# 36440  Commercial associate  Secondary / secondary special            Married
# 36445  Commercial associate  Secondary / secondary special            Married
# 36446  Commercial associate  Secondary / secondary special            Married
# 36450               Working  Secondary / secondary special            Married
#
#        NAME_HOUSING_TYPE OCCUPATION_TYPE  CNT_FAM_MEMBERS STATUS
# 0       Rented apartment             NaN              2.0      1
# 1       Rented apartment             NaN              2.0      1
# 7      House / apartment             NaN              1.0      0
# 8      House / apartment             NaN              1.0      0
# 9      House / apartment             NaN              1.0      0
# ...                  ...             ...              ...    ...
# 36439  House / apartment             NaN              2.0      0
# 36440  House / apartment             NaN              2.0      1
# 36445  House / apartment             NaN              2.0      1
# 36446  House / apartment             NaN              2.0      1
# 36450  House / apartment             NaN              2.0      0
#
# [11323 rows x 11 columns]

# %%
df['OCCUPATION_TYPE'] = df['OCCUPATION_TYPE'].fillna('Jobless')
df
# Out:
#       CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0               M            Y               Y             0
# 1               M            Y               Y             0
# 2               M            Y               Y             0
# 3               F            N               Y             0
# 4               F            N               Y             0
# ...           ...          ...             ...           ...
# 36452           M            Y               Y             0
# 36453           F            N               Y             0
# 36454           F            N               Y             0
# 36455           F            N               Y             0
# 36456           M            N               Y             0
#
#            NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0                   Working               Higher education
# 1                   Working               Higher education
# 2                   Working  Secondary / secondary special
# 3      Commercial associate  Secondary / secondary special
# 4      Commercial associate  Secondary / secondary special
# ...                     ...                            ...
# 36452               Working  Secondary / secondary special
# 36453  Commercial associate               Higher education
# 36454             Pensioner               Higher education
# 36455               Working  Secondary / secondary special
# 36456               Working  Secondary / secondary special
#
#          NAME_FAMILY_STATUS  NAME_HOUSING_TYPE OCCUPATION_TYPE  \
# 0            Civil marriage   Rented apartment         Jobless
# 1            Civil marriage   Rented apartment         Jobless
# 2                   Married  House / apartment  Security staff
# 3      Single / not married  House / apartment     Sales staff
# 4      Single / not married  House / apartment     Sales staff
# ...                     ...                ...             ...
# 36452               Married  House / apartment        Managers
# 36453               Married  House / apartment  Medicine staff
# 36454               Married  House / apartment  Medicine staff
# 36455               Married  House / apartment     Sales staff
# 36456  Single / not married   Rented apartment        Laborers
#
#        CNT_FAM_MEMBERS STATUS
# 0                  2.0      1
# 1                  2.0      1
# 2                  2.0      1
# 3                  1.0      0
# 4                  1.0      0
# ...                ...    ...
# 36452              2.0      1
# 36453              2.0      1
# 36454              2.0      1
# 36455              2.0      1
# 36456              1.0      0
#
# [36457 rows x 11 columns]

# %% [markdown]
# 수치가 0인값을 대체할 팰요가 없기 때문에
# StandardScaler 생략

# %%
from sklearn.preprocessing import LabelEncoder

drugs_encoder = LabelEncoder()
targets = drugs_encoder.fit_transform(df['STATUS'].tolist())
df['STATUS'] = targets

genders_encoder = LabelEncoder()
genders = genders_encoder.fit_transform(df['CODE_GENDER'].tolist())
df['CODE_GENDER'] = genders

car_encoder = LabelEncoder()
car = car_encoder.fit_transform(df['FLAG_OWN_CAR'].tolist())
df['FLAG_OWN_CAR'] = car

own_realty_encoder = LabelEncoder()
own_realty = own_realty_encoder.fit_transform(df['FLAG_OWN_REALTY'].tolist())
df['FLAG_OWN_REALTY'] = own_realty

income_type_encoder = LabelEncoder()
income_type = income_type_encoder.fit_transform(df['NAME_INCOME_TYPE'].tolist())
df['NAME_INCOME_TYPE'] = income_type

income_type_encoder = LabelEncoder()
income_type = income_type_encoder.fit_transform(df['NAME_INCOME_TYPE'].tolist())
df['NAME_INCOME_TYPE'] = income_type

education_encoder = LabelEncoder()
education = education_encoder.fit_transform(df['NAME_EDUCATION_TYPE'].tolist())
df['NAME_EDUCATION_TYPE'] = education

family_encoder = LabelEncoder()
family = family_encoder.fit_transform(df['NAME_FAMILY_STATUS'].tolist())
df['NAME_FAMILY_STATUS'] = family

housing_type_encoder = LabelEncoder()
housing_type = housing_type_encoder.fit_transform(df['NAME_HOUSING_TYPE'].tolist())
df['NAME_HOUSING_TYPE'] = housing_type

occupation_encoder = LabelEncoder()
occupation = occupation_encoder.fit_transform(df['OCCUPATION_TYPE'].tolist())
df['OCCUPATION_TYPE'] = occupation

family_members_encoder = LabelEncoder()
family_members = family_members_encoder.fit_transform(df['CNT_FAM_MEMBERS'].tolist())
df['CNT_FAM_MEMBERS'] = family_members
df
# Out:
#        CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0                1             1                1             0
# 1                1             1                1             0
# 2                1             1                1             0
# 3                0             0                1             0
# 4                0             0                1             0
# ...            ...           ...              ...           ...
# 36452            1             1                1             0
# 36453            0             0                1             0
# 36454            0             0                1             0
# 36455            0             0                1             0
# 36456            1             0                1             0
#
#        NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  NAME_FAMILY_STATUS  \
# 0                     4                    1                   0
# 1                     4                    1                   0
# 2                     4                    4                   1
# 3                     0                    4                   3
# 4                     0                    4                   3
# ...                 ...                  ...                 ...
# 36452                 4                    4                   1
# 36453                 0                    1                   1
# 36454                 1                    1                   1
# 36455                 4                    4                   1
# 36456                 4                    4                   3
#
#        NAME_HOUSING_TYPE  OCCUPATION_TYPE  CNT_FAM_MEMBERS  STATUS
# 0                      4                8                1       1
# 1                      4                8                1       1
# 2                      1               17                1       1
# 3                      1               15                0       0
# 4                      1               15                0       0
# ...                  ...              ...              ...     ...
# 36452                  1               11                1       1
# 36453                  1               12                1       1
# 36454                  1               12                1       1
# 36455                  1               15                1       1
# 36456                  4                9                0       0
#
# [36457 rows x 11 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, GridSearchCV

features = df.iloc[:, :-1]
targets = df.iloc[:, -1]
display(features)
display(targets)
X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size=0.2, random_state=124, stratify=targets)
# Out:
#        CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0                1             1                1             0
# 1                1             1                1             0
# 2                1             1                1             0
# 3                0             0                1             0
# 4                0             0                1             0
# ...            ...           ...              ...           ...
# 36452            1             1                1             0
# 36453            0             0                1             0
# 36454            0             0                1             0
# 36455            0             0                1             0
# 36456            1             0                1             0
#
#        NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  NAME_FAMILY_STATUS  \
# 0                     4                    1                   0
# 1                     4                    1                   0
# 2                     4                    4                   1
# 3                     0                    4                   3
# 4                     0                    4                   3
# ...                 ...                  ...                 ...
# 36452                 4                    4                   1
# 36453                 0                    1                   1
# 36454                 1                    1                   1
# 36455                 4                    4                   1
# 36456                 4                    4                   3
#
#        NAME_HOUSING_TYPE  OCCUPATION_TYPE  CNT_FAM_MEMBERS
# 0                      4                8                1
# 1                      4                8                1
# 2                      1               17                1
# 3                      1               15                0
# 4                      1               15                0
# ...                  ...              ...              ...
# 36452                  1               11                1
# 36453                  1               12                1
# 36454                  1               12                1
# 36455                  1               15                1
# 36456                  4                9                0
#
# [36457 rows x 10 columns]
# 0        1
# 1        1
# 2        1
# 3        0
# 4        0
#         ..
# 36452    1
# 36453    1
# 36454    1
# 36455    1
# 36456    0
# Name: STATUS, Length: 36457, dtype: int64

# %%
dtc = DecisionTreeClassifier()
parameters = {'max_depth': [3, 4, 5], 'min_samples_split': [15, 16, 17]}

# %%
g_dtc = GridSearchCV(dtc, param_grid=parameters, cv=10, refit=True, return_train_score=True)

# %%
g_dtc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [3, 4, 5],
#                          'min_samples_split': [15, 16, 17]},
#              return_train_score=True)

# %%
g_dtc.cv_results_
# Out:
# {'mean_fit_time': array([0.02145314, 0.01975565, 0.02283802, 0.0239471 , 0.03141801,
#         0.02493765, 0.0283282 , 0.03590596, 0.02901988]),
#  'std_fit_time': array([0.00341529, 0.00107706, 0.00092697, 0.00227662, 0.01117832,
#         0.00243365, 0.00161432, 0.01074554, 0.00316713]),
#  'mean_score_time': array([0.00209863, 0.00198383, 0.00239365, 0.00238402, 0.00259249,
#         0.00239182, 0.00258825, 0.00339117, 0.0022943 ]),
#  'std_score_time': array([5.48225780e-04, 7.84089077e-06, 6.60779869e-04, 4.86263165e-04,
#         9.12907598e-04, 6.53445374e-04, 4.95214185e-04, 8.03701266e-04,
#         4.52051937e-04]),
#  'param_max_depth': masked_array(data=[5, 5, 5, 6, 6, 6, 7, 7, 7],
#               mask=[False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_split': masked_array(data=[7, 8, 9, 7, 8, 9, 7, 8, 9],
#               mask=[False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_depth': 5, 'min_samples_split': 7},
#   {'max_depth': 5, 'min_samples_split': 8},
#   {'max_depth': 5, 'min_samples_split': 9},
#   {'max_depth': 6, 'min_samples_split': 7},
#   {'max_depth': 6, 'min_samples_split': 8},
#   {'max_depth': 6, 'min_samples_split': 9},
#   {'max_depth': 7, 'min_samples_split': 7},
#   {'max_depth': 7, 'min_samples_split': 8},
#   {'max_depth': 7, 'min_samples_split': 9}],
#  'split0_test_score': array([0.50428522, 0.50428522, 0.50428522, 0.50737059, 0.50737059,
#         0.50737059, 0.51799794, 0.51799794, 0.51799794]),
#  'split1_test_score': array([0.52211176, 0.52211176, 0.52211176, 0.52142612, 0.52142612,
#         0.52176894, 0.51559822, 0.51559822, 0.51559822]),
#  'split2_test_score': array([0.50462804, 0.50462804, 0.50462804, 0.50257113, 0.50257113,
#         0.50257113, 0.51799794, 0.51799794, 0.51799794]),
#  'split3_test_score': array([0.51594104, 0.51594104, 0.51594104, 0.52896812, 0.52896812,
#         0.52896812, 0.52931094, 0.52931094, 0.52931094]),
#  'split4_test_score': array([0.50737059, 0.50737059, 0.50737059, 0.51662667, 0.51662667,
#         0.51662667, 0.50668495, 0.50668495, 0.50668495]),
#  'split5_test_score': array([0.50205761, 0.50205761, 0.50205761, 0.51131687, 0.51200274,
#         0.51131687, 0.50377229, 0.50342936, 0.50308642]),
#  'split6_test_score': array([0.51131687, 0.51131687, 0.51131687, 0.51234568, 0.51234568,
#         0.51234568, 0.51817558, 0.51817558, 0.51851852]),
#  'split7_test_score': array([0.51303155, 0.51268861, 0.51268861, 0.51406036, 0.51406036,
#         0.51406036, 0.51611797, 0.51611797, 0.51611797]),
#  'split8_test_score': array([0.50857339, 0.50857339, 0.50857339, 0.51954733, 0.51954733,
#         0.51954733, 0.521262  , 0.521262  , 0.521262  ]),
#  'split9_test_score': array([0.50994513, 0.50994513, 0.50994513, 0.51200274, 0.51200274,
#         0.51200274, 0.51200274, 0.51200274, 0.51200274]),
#  'mean_test_score': array([0.50992612, 0.50989183, 0.50989183, 0.51462356, 0.51469215,
#         0.51465784, 0.51589206, 0.51585776, 0.51585776]),
#  'std_test_score': array([0.00571324, 0.00569549, 0.00569549, 0.00708147, 0.00705238,
#         0.00711507, 0.006855  , 0.00691613, 0.00699055]),
#  'rank_test_score': array([7, 8, 8, 6, 4, 5, 1, 2, 2]),
#  'split0_train_score': array([0.51935386, 0.51935386, 0.51935386, 0.52186833, 0.52186833,
#         0.52186833, 0.52750686, 0.52750686, 0.52750686]),
#  'split1_train_score': array([0.51737275, 0.51737275, 0.51737275, 0.52087778, 0.52087778,
#         0.52083968, 0.52472569, 0.52476379, 0.52472569]),
#  'split2_train_score': array([0.52156355, 0.52156355, 0.52156355, 0.52438281, 0.52438281,
#         0.52438281, 0.5307452 , 0.5307071 , 0.5307071 ]),
#  'split3_train_score': array([0.51489637, 0.51489637, 0.51489637, 0.51981103, 0.51981103,
#         0.51981103, 0.52091588, 0.52091588, 0.52091588]),
#  'split4_train_score': array([0.51866809, 0.51866809, 0.51866809, 0.5245352 , 0.5245352 ,
#         0.5245352 , 0.52884029, 0.52884029, 0.52884029]),
#  'split5_train_score': array([0.52226751, 0.52222942, 0.52222942, 0.5281725 , 0.52813441,
#         0.52813441, 0.53289649, 0.53285839, 0.5328203 ]),
#  'split6_train_score': array([0.51632443, 0.51632443, 0.51632443, 0.52173416, 0.52173416,
#         0.52173416, 0.52523906, 0.52523906, 0.52523906]),
#  'split7_train_score': array([0.51621014, 0.51621014, 0.51621014, 0.51956265, 0.51956265,
#         0.51956265, 0.52215322, 0.52215322, 0.52215322]),
#  'split8_train_score': array([0.51365766, 0.51365766, 0.51365766, 0.51716256, 0.51716256,
#         0.51716256, 0.52005791, 0.52005791, 0.52005791]),
#  'split9_train_score': array([0.51937217, 0.51937217, 0.51937217, 0.52097223, 0.52097223,
#         0.52097223, 0.52481999, 0.52481999, 0.52481999]),
#  'mean_train_score': array([0.51796865, 0.51796484, 0.51796484, 0.52190793, 0.52190412,
#         0.52190031, 0.52579006, 0.52578625, 0.52577863]),
#  'std_train_score': array([0.00264492, 0.00263874, 0.00263874, 0.00294375, 0.00293566,
#         0.00293701, 0.00399406, 0.00398158, 0.00397581])}

# %%
result_df = pd.DataFrame(g_dtc.cv_results_)[['params', 'mean_test_score', 'rank_test_score', 
           'split0_test_score', 'split1_test_score', 'split2_test_score']]
result_df
# Out:
#                                      params  mean_test_score  rank_test_score  \
# 0  {'max_depth': 5, 'min_samples_split': 7}         0.509926                7
# 1  {'max_depth': 5, 'min_samples_split': 8}         0.509892                8
# 2  {'max_depth': 5, 'min_samples_split': 9}         0.509892                8
# 3  {'max_depth': 6, 'min_samples_split': 7}         0.514624                6
# 4  {'max_depth': 6, 'min_samples_split': 8}         0.514692                4
# 5  {'max_depth': 6, 'min_samples_split': 9}         0.514658                5
# 6  {'max_depth': 7, 'min_samples_split': 7}         0.515892                1
# 7  {'max_depth': 7, 'min_samples_split': 8}         0.515858                2
# 8  {'max_depth': 7, 'min_samples_split': 9}         0.515858                2
#
#    split0_test_score  split1_test_score  split2_test_score
# 0           0.504285           0.522112           0.504628
# 1           0.504285           0.522112           0.504628
# 2           0.504285           0.522112           0.504628
# 3           0.507371           0.521426           0.502571
# 4           0.507371           0.521426           0.502571
# 5           0.507371           0.521769           0.502571
# 6           0.517998           0.515598           0.517998
# 7           0.517998           0.515598           0.517998
# 8           0.517998           0.515598           0.517998

# %%
print(g_dtc.best_params_, g_dtc.best_score_, sep="\n")
# Out:
# {'max_depth': 5, 'min_samples_split': 15}
# 0.5099261201424129
